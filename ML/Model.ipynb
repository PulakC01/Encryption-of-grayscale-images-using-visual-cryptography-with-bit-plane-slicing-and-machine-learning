# %%
import numpy as np
import pandas as pd
import seaborn as sns
import optuna
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree  import DecisionTreeClassifier
import itertools
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

# %%
train=pd.read_csv('Train_data.csv')
test=pd.read_csv('Test_data.csv')
df = pd.concat([train, test], ignore_index=True)
train.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# min        0.00000      0.000000           0.000000      0.000000
# 25%        0.00000      0.000000           0.000000      0.000000
# 50%        0.00000      0.000000           0.000000      0.000000
# 75%        0.00000      0.000000           0.000000      1.000000
# max        1.00000     77.000000           4.000000      1.000000
#
#        num_compromised  ...  dst_host_count  dst_host_srv_count  \
# count     25192.000000  ...    25192.000000        25192.000000
# mean          0.227850  ...      182.532074          115.063036
# std          10.417352  ...       98.993895          110.646850
# min           0.000000  ...        0.000000            0.000000
# 25%           0.000000  ...       84.000000           10.000000
# 50%           0.000000  ...      255.000000           61.000000
# 75%           0.000000  ...      255.000000          255.000000
# max         884.000000  ...      255.000000          255.000000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count            25192.000000            25192.000000
# mean                 0.519791                0.082539
# std                  0.448944                0.187191
# min                  0.000000                0.000000
# 25%                  0.050000                0.000000
# 50%                  0.510000                0.030000
# 75%                  1.000000                0.070000
# max                  1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                 25192.000000                 25192.000000
# mean                      0.147453                     0.031844
# std                       0.308367                     0.110575
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.060000                     0.020000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count          25192.000000              25192.000000          25192.000000
# mean               0.285800                  0.279846              0.117800
# std                0.445316                  0.446075              0.305869
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                1.000000                  1.000000              0.000000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate
# count              25192.000000
# mean                   0.118769
# std                    0.317333
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000
#
# [8 rows x 38 columns]

# %%
#Missing values
total = train.shape[0]
missing_columns = [col for col in train.columns if train[col].isnull().sum() > 0]
for col in missing_columns:
    null_count = train[col].isnull().sum()
    per = (null_count/total) * 100
    print(f"{col}: {null_count} ({round(per, 3)}%)")

# %%
#Duplicate values
print(f"Number of duplicate rows: {train.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0

# %%
plt.figure(figsize=(40,30))
sns.heatmap(train.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x=train['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
#Label Encoding
def le(df):
    for col in df.columns:
        if df[col].dtype == 'object':
                label_encoder = LabelEncoder()
                df[col] = label_encoder.fit_transform(df[col])

le(train)
le(test)

# %%
train.drop(['num_outbound_cmds'], axis=1, inplace=True)
test.drop(['num_outbound_cmds'], axis=1, inplace=True)
train.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       19     9        491          0     0
# 1         0              2       41     9        146          0     0
# 2         0              1       46     5          0          0     0
# 3         0              1       22     9        232       8153     0
# 4         0              1       22     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      1
# 1                      0.00      1
# 2                      0.00      0
# 3                      0.01      1
# 4                      0.00      1
#
# [5 rows x 41 columns]

# %%
X_train = train.drop(['class'], axis=1)
Y_train = train['class']

# %%
rfc = RandomForestClassifier()

rfe = RFE(rfc, n_features_to_select=10)
rfe = rfe.fit(X_train, Y_train)

feature_map = [(i, v) for i, v in itertools.zip_longest(rfe.get_support(), X_train.columns)]
selected_features = [v for i, v in feature_map if i==True]

selected_features
# Out:
# ['protocol_type',
#  'service',
#  'flag',
#  'src_bytes',
#  'dst_bytes',
#  'count',
#  'same_srv_rate',
#  'diff_srv_rate',
#  'dst_host_srv_count',
#  'dst_host_same_srv_rate']

# %%
X_train = X_train[selected_features]

scale = StandardScaler()
X_train = scale.fit_transform(X_train)
test = scale.fit_transform(test)

x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, train_size=0.70, random_state=2)

# %%
def objective(trial):
    dt_max_depth = trial.suggest_int('dt_max_depth', 2, 32, log=False)
    dt_max_features = trial.suggest_int('dt_max_features', 2, 10, log=False)
    classifier_obj = DecisionTreeClassifier(max_features = dt_max_features, max_depth = dt_max_depth)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
study_dt = optuna.create_study(direction='maximize')
study_dt.optimize(objective, n_trials=30)
print(study_dt.best_trial)
# Out:
# [I 2022-10-19 11:10:28,282] A new study created in memory with name: no-name-af92c333-d830-46c0-8c5b-6ca792c27307
# [I 2022-10-19 11:10:28,302] Trial 0 finished with value: 0.9693040486901296 and parameters: {'dt_max_depth': 4, 'dt_max_features': 5}. Best is trial 0 with value: 0.9693040486901296.
# [I 2022-10-19 11:10:28,344] Trial 1 finished with value: 0.9948399047367028 and parameters: {'dt_max_depth': 22, 'dt_max_features': 10}. Best is trial 1 with value: 0.9948399047367028.
# [I 2022-10-19 11:10:28,375] Trial 2 finished with value: 0.9958983858163535 and parameters: {'dt_max_depth': 29, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,394] Trial 3 finished with value: 0.9931198729822704 and parameters: {'dt_max_depth': 23, 'dt_max_features': 3}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,426] Trial 4 finished with value: 0.9941783540619211 and parameters: {'dt_max_depth': 19, 'dt_max_features': 7}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,457] Trial 5 finished with value: 0.9912675310928817 and parameters: {'dt_max_depth': 9, 'dt_max_features': 6}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,482] Trial 6 finished with value: 0.9945752844667901 and parameters: {'dt_max_depth': 18, 'dt_max_features': 7}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,522] Trial 7 finished with value: 0.9944429743318338 and parameters: {'dt_max_depth': 24, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,533] Trial 8 finished with value: 0.9327864514421804 and parameters: {'dt_max_depth': 2, 'dt_max_features': 5}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,547] Trial 9 finished with value: 0.9416512304842551 and parameters: {'dt_max_depth': 3, 'dt_max_features': 2}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,617] Trial 10 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 30, 'dt_max_features': 10}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,672] Trial 11 finished with value: 0.9951045250066155 and parameters: {'dt_max_depth': 31, 'dt_max_features': 10}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,712] Trial 12 finished with value: 0.9941783540619211 and parameters: {'dt_max_depth': 32, 'dt_max_features': 9}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,754] Trial 13 finished with value: 0.9949722148716592 and parameters: {'dt_max_depth': 28, 'dt_max_features': 9}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,786] Trial 14 finished with value: 0.9951045250066155 and parameters: {'dt_max_depth': 12, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,842] Trial 15 finished with value: 0.9945752844667901 and parameters: {'dt_max_depth': 27, 'dt_max_features': 10}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,895] Trial 16 finished with value: 0.9943106641968775 and parameters: {'dt_max_depth': 26, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,931] Trial 17 finished with value: 0.9939137337920084 and parameters: {'dt_max_depth': 12, 'dt_max_features': 7}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:28,980] Trial 18 finished with value: 0.9944429743318338 and parameters: {'dt_max_depth': 32, 'dt_max_features': 9}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,025] Trial 19 finished with value: 0.9949722148716592 and parameters: {'dt_max_depth': 21, 'dt_max_features': 9}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,041] Trial 20 finished with value: 0.9941783540619211 and parameters: {'dt_max_depth': 13, 'dt_max_features': 5}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,088] Trial 21 finished with value: 0.9936491135220958 and parameters: {'dt_max_depth': 15, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,120] Trial 22 finished with value: 0.9940460439269648 and parameters: {'dt_max_depth': 9, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,152] Trial 23 finished with value: 0.9940460439269648 and parameters: {'dt_max_depth': 29, 'dt_max_features': 6}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,184] Trial 24 finished with value: 0.9900767398782747 and parameters: {'dt_max_depth': 7, 'dt_max_features': 10}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,214] Trial 25 finished with value: 0.9945752844667901 and parameters: {'dt_max_depth': 12, 'dt_max_features': 6}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,262] Trial 26 finished with value: 0.9933844932521831 and parameters: {'dt_max_depth': 25, 'dt_max_features': 9}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,295] Trial 27 finished with value: 0.9947075946017465 and parameters: {'dt_max_depth': 16, 'dt_max_features': 7}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,327] Trial 28 finished with value: 0.9943106641968775 and parameters: {'dt_max_depth': 30, 'dt_max_features': 8}. Best is trial 2 with value: 0.9958983858163535.
# [I 2022-10-19 11:10:29,342] Trial 29 finished with value: 0.9837258534003704 and parameters: {'dt_max_depth': 6, 'dt_max_features': 4}. Best is trial 2 with value: 0.9958983858163535.
# FrozenTrial(number=2, values=[0.9958983858163535], datetime_start=datetime.datetime(2022, 10, 19, 11, 10, 28, 344299), datetime_complete=datetime.datetime(2022, 10, 19, 11, 10, 28, 375976), params={'dt_max_depth': 29, 'dt_max_features': 8}, distributions={'dt_max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'dt_max_features': IntDistribution(high=10, log=False, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=2, state=TrialState.COMPLETE, value=None)

# %%
dt = DecisionTreeClassifier(max_features = study_dt.best_trial.params['dt_max_features'], max_depth = study_dt.best_trial.params['dt_max_depth'])
dt.fit(x_train, y_train)

dt_train, dt_test = dt.score(x_train, y_train), dt.score(x_test, y_test)

print(f"Train Score: {dt_train}")
print(f"Test Score: {dt_test}")
# Out:
# Train Score: 1.0
# Test Score: 0.9940460439269648

# %%
fig = plt.figure(figsize = (30,12))
tree.plot_tree(dt, filled=True);
plt.show()
